# %%
# Import libraries
import cv2 
import numpy as np

def nothing(x): pass

# Load image
image = cv2.imread('webcam.png')

# Create a window
cv2.namedWindow('image', cv2.WINDOW_NORMAL) 
cv2.resizeWindow('image', 900, 700)

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing) 
cv2.createTrackbar('SMin', 'image', 0, 255, nothing) 
cv2.createTrackbar('VMin', 'image', 0, 255, nothing) 
cv2.createTrackbar('HMax', 'image', 0, 179, nothing) 
cv2.createTrackbar('SMax', 'image', 0, 255, nothing) 
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179) 
cv2.setTrackbarPos('SMax', 'image', 255) 
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0 
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):

    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)
    
    # Convert grayscale image to color image for displaying simultaneous
    mask_3_channel = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
    
    # Stack images
    numpy_horizontal = np.hstack((image, result, mask_3_channel))
    
    # Display HSV values of some colours
    cv2.putText(numpy_horizontal, 'Black: (0, 0, 0)', (130, 15), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'White: (0, 0, 255)', (130, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Red: (0, 255, 255)', (130, 45), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Green: (60, 255, 255)', (130, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Blue: (120, 255, 255)', (130, 75), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display stacked image, press q to quit
    cv2.imshow('image', numpy_horizontal)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 38 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 40 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 43 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 49 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 51 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 53 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 54 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 55 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 56 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 57 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 58 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 68 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 70 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 70 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 84 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 89 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 91 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 92 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 93 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 92 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 93 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 94 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 99 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 104 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 112 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 118 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 120 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 122 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 123 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 124 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 125 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 126 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 127 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 128 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 129 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 130 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 131 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 132 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 133 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 135 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 139 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 142 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 144 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 146 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 148 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 149 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 150 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 151 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 152 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 153 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 154 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 155 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 156 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 157 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 158 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 159 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 160 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 161 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 163 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 164 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 165 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 166 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 167 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 166 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 165 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 164 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 163 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 162 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 161 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 160 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 159 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 158 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 157 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 156 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 155 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 154 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 153 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 152 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 151 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 150 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 149 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 148 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 146 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 18, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 32, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 39, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 42, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 44, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 47, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 48, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 50, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 52, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 53, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 55, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 56, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 57, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 58, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 59, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 60, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 61, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 63, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 65, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 66, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 67, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 68, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 69, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin =
(hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 36), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 37), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 86), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 120), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 136), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 159), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 174), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 179), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 184), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 187), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 188), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 189), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 188), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 172), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 95), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 86), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 84), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 81), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 80), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 79), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 78), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 77), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 76), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 77), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 80), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 88), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 100), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 102), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 103), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 104), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 105), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 106), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 107), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 112), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 113), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 117), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 118), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 121), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 122), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 123), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 124), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 125), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 126), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 127), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 128), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 129), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 130), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 131), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 132), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 133), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 134), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 135), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 136), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 137), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 138), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 139), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 140), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 141), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 142), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 143), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 144), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 145), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 146), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 145), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 144), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 143), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 144), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 145), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 146), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 147), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 148), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 149), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 150), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 149), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 150), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 151), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 152), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 153), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 154), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 155), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 157), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 158), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 159), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 160), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 161), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 162), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 163), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 164), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 165), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 166), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 167), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 168), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 169), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 170), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 171), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 172), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 254, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 253, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 252, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 251, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 250, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 249, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 248, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 247, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 248, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 249, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 250, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 251, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 252, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 254, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 250)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 248)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 247)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 245)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 244)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 243)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 242)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 241)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 240)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 239)
# ...
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 142 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 141 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 140 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 139 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 138 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 137 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 136 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 135 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 134 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 133 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 132 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 131 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 132 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 133 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 139 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 152 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 154 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 155 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 156 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 157 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 158 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 159 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 160 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 161 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 160 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 159 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 158 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 157 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 155 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 152 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 150 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 149 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 148 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 146 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 144 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 142 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 140 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 139 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 138 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 137 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 136 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 135 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 134 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 133 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 132 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 131 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 130 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 129 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 128 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 127 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 126 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 125 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 124 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 123 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 122 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 121 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 120 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 118 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 117 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 116 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 114 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 113 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 112 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 111 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 109 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 107 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 106 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 104 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 103 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 102 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 101 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 102 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 103 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 104 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 105 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 106 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 107 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 108 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 109 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 110 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 111 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 112 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 113 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 114 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 115 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 116 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 117 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 118 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 119 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 120 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 121 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 122 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 123 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 125 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 127 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 128 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 129 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 133 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 136 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 138 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 140 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 142 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 144 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 146 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 148 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 150 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 151 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 152 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 154 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 155 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 156 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 157 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 158 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 159 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 158 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 157 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 156 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 155 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 154 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 152 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 151 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 146 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 144 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 138 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 134 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 133 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 131 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 130 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 129 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 127 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 126 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 125 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 124 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 123 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 122 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 121 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 120 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 119 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 118 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 117 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 116 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 115 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 114 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 113 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 112 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 111 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 109 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 108 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 106 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 104 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 103 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 102 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 101 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 102 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 103 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 104 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 105 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 106 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 107 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 111 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 122 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 123 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 124 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 125 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 126 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 127 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 128 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 129 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 130 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 131 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 132 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 133 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 135 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 136 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 137 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 138 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 139 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 142 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 148 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 149 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 148 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 146 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 145 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 144 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 144 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 143 , sMin = 62, vMin = 173), (hMax = 172 , sMax = 255, vMax = 255)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9280\1340735694.py in <module>
#      33
#      34     # Get current positions of all trackbars
# ---> 35     hMin = cv2.getTrackbarPos('HMin', 'image')
#      36     sMin = cv2.getTrackbarPos('SMin', 'image')
#      37     vMin = cv2.getTrackbarPos('VMin', 'image')
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2561: error: (-27:Null pointer) NULL window: 'image' in function 'cvGetTrackbarPos'
